# %% [markdown]
# # 데이터 준비하기

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %% [markdown]
# 이미지 확인

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %% [markdown]
# 이미지 크기 확인

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %% [markdown]
# 코드로 이미지 나누기
# - 왼쪽 : 라벨
# - 오른쪽 : 스케치

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    photo = img[:, :w, :] 
    photo = tf.cast(photo, tf.float32)
    painted = img[:, w:, :] 
    painted = tf.cast(painted, tf.float32)
    return normalize(painted), normalize(photo)

f = data_path + os.listdir(data_path)[1]
painted, photo = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(painted))
plt.subplot(1,2,2); plt.imshow(denormalize(photo))

# %% [markdown]
# # Data augmentation
#
# 1. 두 이미지가 채널 축으로 연결됩니다. (tf.concat). 두 이미지가 각각 3채널인 경우 6채널이 됩니다.
# 2. 1의 결과에 각 50% 확률로 Refection padding 또는 constant padding이 30픽셀의 pad width 만큼적용됩니다. (tf.pad)
# 3. 2의 결과에서 (256,256,6) 크기를 가진 이미지를 임의로 잘라냅니다. (tf.image.random_crop)
# 4. 3의 결과를 50% 확률로 가로로 뒤집습니다. (tf.image.random_flip_left_right)
# 5. 4의 결과를 50% 확률로 세로로 뒤집습니다. (tf.image.random_flip_up_down)
# 6. 5의 결과를 50% 확률로 회전시킵니다. (tf.image.rot90)

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(painted, photo):
    stacked = tf.concat([painted, photo], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %% [markdown]
# #### 학습 데이터에 적용하기

# %%
from tensorflow import data

def get_train(img_path):
    painted, photo = load_img(img_path)
    painted, photo = apply_augmentation(painted, photo)
    return painted, photo

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
painted, photo = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(painted[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(photo[0].astype(np.uint8))

# %% [markdown]
# # U-Net Generator

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
from tensorflow.keras import layers, Input, Model

class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # Discriminator

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# # 손실함수 & optimizer

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %% [markdown]
# # 학습
#
# - 10 epochs 학습

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 10

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (painted, photo) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(painted, photo)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9901
# L1_loss:0.3067
# Discriminator_loss:1.2575
#
# EPOCH[1] - STEP[20]
# Generator_loss:0.8849
# L1_loss:0.2599
# Discriminator_loss:1.2487
#
# EPOCH[1] - STEP[30]
# Generator_loss:0.8717
# L1_loss:0.2117
# Discriminator_loss:1.4959
#
# EPOCH[1] - STEP[40]
# Generator_loss:0.8700
# L1_loss:0.1680
# Discriminator_loss:1.2963
#
# EPOCH[1] - STEP[50]
# Generator_loss:0.9239
# L1_loss:0.2014
# Discriminator_loss:1.2769
#
# EPOCH[1] - STEP[60]
# Generator_loss:0.9431
# L1_loss:0.2050
# Discriminator_loss:1.2432
#
# EPOCH[1] - STEP[70]
# Generator_loss:0.9037
# L1_loss:0.2285
# Discriminator_loss:1.0465
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.1211
# L1_loss:0.1922
# Discriminator_loss:1.1687
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.1028
# L1_loss:0.1991
# Discriminator_loss:1.0242
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.1461
# L1_loss:0.2085
# Discriminator_loss:0.9936
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.0542
# L1_loss:0.1684
# Discriminator_loss:0.8841
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.2569
# L1_loss:0.1802
# Discriminator_loss:0.8930
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.2874
# L1_loss:0.1911
# Discriminator_loss:1.0032
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.2708
# L1_loss:0.1902
# Discriminator_loss:0.9174
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.2836
# L1_loss:0.1771
# Discriminator_loss:0.8566
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.5498
# L1_loss:0.1808
# Discriminator_loss:0.9781
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.3138
# L1_loss:0.1360
# Discriminator_loss:0.9935
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.4201
# L1_loss:0.1714
# Discriminator_loss:1.4030
#
# EPOCH[1] - STEP[190]
# Generator_loss:0.8657
# L1_loss:0.1829
# Discriminator_loss:0.8924
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.0935
# L1_loss:0.1982
# Discriminator_loss:0.7115
#
# EPOCH[1] - STEP[210]
# Generator_loss:0.6135
# L1_loss:0.1654
# Discriminator_loss:1.0865
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.3664
# L1_loss:0.1775
# Discriminator_loss:0.6005
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.9893
# L1_loss:0.1710
# Discriminator_loss:0.5362
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.8453
# L1_loss:0.2004
# Discriminator_loss:0.8288
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.6803
# L1_loss:0.2338
# Discriminator_loss:0.3093
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.9432
# L1_loss:0.2028
# Discriminator_loss:0.8462
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.4020
# L1_loss:0.1832
# Discriminator_loss:1.0233
#
# EPOCH[2] - STEP[30]
# Generator_loss:1.7281
# L1_loss:0.1960
# Discriminator_loss:0.4704
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.8586
# L1_loss:0.1587
# Discriminator_loss:0.9449
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.0156
# L1_loss:0.1831
# Discriminator_loss:0.4547
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.3680
# L1_loss:0.1635
# Discriminator_loss:0.5652
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.8092
# L1_loss:0.1849
# Discriminator_loss:0.6681
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.9446
# L1_loss:0.2009
# Discriminator_loss:1.5883
#
# EPOCH[2] - STEP[90]
# Generator_loss:2.3070
# L1_loss:0.1702
# Discriminator_loss:0.6352
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.1950
# L1_loss:0.1672
# Discriminator_loss:1.2274
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.7874
# L1_loss:0.1855
# Discriminator_loss:0.4244
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.2717
# L1_loss:0.2102
# Discriminator_loss:0.5061
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.7502
# L1_loss:0.1676
# Discriminator_loss:0.6058
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.3317
# L1_loss:0.1862
# Discriminator_loss:0.5211
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.4710
# L1_loss:0.1700
# Discriminator_loss:0.6976
#
# EPOCH[2] - STEP[160]
# Generator_loss:0.7418
# L1_loss:0.1829
# Discriminator_loss:1.3225
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.6554
# L1_loss:0.1844
# Discriminator_loss:0.5454
#
# EPOCH[2] - STEP[180]
# Generator_loss:0.9109
# L1_loss:0.1811
# Discriminator_loss:1.0922
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.2758
# L1_loss:0.2190
# Discriminator_loss:1.5758
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.8890
# L1_loss:0.1777
# Discriminator_loss:0.4843
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.7828
# L1_loss:0.1557
# Discriminator_loss:1.3981
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.1245
# L1_loss:0.2108
# Discriminator_loss:0.5183
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.4155
# L1_loss:0.1747
# Discriminator_loss:1.2087
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.0391
# L1_loss:0.1866
# Discriminator_loss:0.7824
#
# EPOCH[2] - STEP[250]
# Generator_loss:0.9341
# L1_loss:0.2271
# Discriminator_loss:2.3369
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.1404
# L1_loss:0.2225
# Discriminator_loss:0.6218
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.4753
# L1_loss:0.1627
# Discriminator_loss:0.5000
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.0379
# L1_loss:0.2086
# Discriminator_loss:1.0349
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.0195
# L1_loss:0.1957
# Discriminator_loss:0.8462
#
# EPOCH[3] - STEP[50]
# Generator_loss:0.9824
# L1_loss:0.1862
# Discriminator_loss:0.7116
#
# EPOCH[3] - STEP[60]
# Generator_loss:0.5519
# L1_loss:0.1894
# Discriminator_loss:1.4124
#
# EPOCH[3] - STEP[70]
# Generator_loss:1.9875
# L1_loss:0.1534
# Discriminator_loss:0.6989
#
# EPOCH[3] - STEP[80]
# Generator_loss:0.5986
# L1_loss:0.1955
# Discriminator_loss:1.0011
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.8181
# L1_loss:0.1651
# Discriminator_loss:0.5473
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.7118
# L1_loss:0.1702
# Discriminator_loss:0.9204
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.8144
# L1_loss:0.2274
# Discriminator_loss:0.2584
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.2092
# L1_loss:0.1841
# Discriminator_loss:0.5649
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.7000
# L1_loss:0.1813
# Discriminator_loss:0.6858
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.2895
# L1_loss:0.2202
# Discriminator_loss:0.4462
#
# EPOCH[3] - STEP[150]
# Generator_loss:3.2128
# L1_loss:0.1644
# Discriminator_loss:1.4100
#
# EPOCH[3] - STEP[160]
# Generator_loss:0.9913
# L1_loss:0.1873
# Discriminator_loss:0.7415
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.1040
# L1_loss:0.1945
# Discriminator_loss:0.6478
#
# EPOCH[3] - STEP[180]
# Generator_loss:0.4824
# L1_loss:0.2120
# Discriminator_loss:1.6433
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.5950
# L1_loss:0.1607
# Discriminator_loss:0.7158
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.7660
# L1_loss:0.1897
# Discriminator_loss:0.4889
#
# EPOCH[3] - STEP[210]
# Generator_loss:2.4333
# L1_loss:0.2240
# Discriminator_loss:0.2443
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.5100
# L1_loss:0.1657
# Discriminator_loss:2.0404
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.2573
# L1_loss:0.1798
# Discriminator_loss:0.7792
#
# EPOCH[3] - STEP[240]
# Generator_loss:0.8966
# L1_loss:0.1808
# Discriminator_loss:0.7754
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.5591
# L1_loss:0.1895
# Discriminator_loss:0.5825
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.5101
# L1_loss:0.1823
# Discriminator_loss:0.7226
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.0976
# L1_loss:0.1751
# Discriminator_loss:0.9198
#
# EPOCH[4] - STEP[30]
# Generator_loss:1.7608
# L1_loss:0.1684
# Discriminator_loss:0.5821
#
# EPOCH[4] - STEP[40]
# Generator_loss:0.8535
# L1_loss:0.1654
# Discriminator_loss:0.9745
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.9685
# L1_loss:0.1584
# Discriminator_loss:1.3220
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.1818
# L1_loss:0.1849
# Discriminator_loss:0.6319
#
# EPOCH[4] - STEP[70]
# Generator_loss:0.9235
# L1_loss:0.1975
# Discriminator_loss:0.6970
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.5264
# L1_loss:0.2185
# Discriminator_loss:0.2318
#
# EPOCH[4] - STEP[90]
# Generator_loss:0.9790
# L1_loss:0.2065
# Discriminator_loss:0.6538
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.3646
# L1_loss:0.1741
# Discriminator_loss:0.8532
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.6349
# L1_loss:0.1589
# Discriminator_loss:1.5168
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.2855
# L1_loss:0.2091
# Discriminator_loss:0.1900
#
# EPOCH[4] - STEP[130]
# Generator_loss:0.5592
# L1_loss:0.1626
# Discriminator_loss:1.2948
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.0638
# L1_loss:0.2117
# Discriminator_loss:0.6050
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.0726
# L1_loss:0.1914
# Discriminator_loss:0.6324
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.1905
# L1_loss:0.1860
# Discriminator_loss:0.5867
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.1111
# L1_loss:0.2163
# Discriminator_loss:0.6535
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.4148
# L1_loss:0.1781
# Discriminator_loss:0.8904
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.8138
# L1_loss:0.1592
# Discriminator_loss:1.7670
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6950
# L1_loss:0.1946
# Discriminator_loss:0.6315
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.9679
# L1_loss:0.2080
# Discriminator_loss:0.2444
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.3169
# L1_loss:0.1634
# Discriminator_loss:2.8637
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.0682
# L1_loss:0.1928
# Discriminator_loss:0.6357
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.0721
# L1_loss:0.1574
# Discriminator_loss:1.0804
#
# EPOCH[4] - STEP[250]
# Generator_loss:2.1724
# L1_loss:0.1516
# Discriminator_loss:0.7821
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.2748
# L1_loss:0.1763
# Discriminator_loss:0.6466
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.2434
# L1_loss:0.1751
# Discriminator_loss:1.9785
#
# EPOCH[5] - STEP[30]
# Generator_loss:2.1358
# L1_loss:0.1745
# Discriminator_loss:0.8632
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.6939
# L1_loss:0.1609
# Discriminator_loss:0.7492
#
# EPOCH[5] - STEP[50]
# Generator_loss:0.1882
# L1_loss:0.1977
# Discriminator_loss:3.0553
#
# EPOCH[5] - STEP[60]
# Generator_loss:0.9632
# L1_loss:0.1755
# Discriminator_loss:0.6156
#
# EPOCH[5] - STEP[70]
# Generator_loss:3.0788
# L1_loss:0.1727
# Discriminator_loss:0.7921
#
# EPOCH[5] - STEP[80]
# Generator_loss:0.9442
# L1_loss:0.1664
# Discriminator_loss:0.8082
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.8643
# L1_loss:0.1623
# Discriminator_loss:0.4008
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.3418
# L1_loss:0.2147
# Discriminator_loss:0.6853
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.3998
# L1_loss:0.2195
# Discriminator_loss:0.5762
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.7554
# L1_loss:0.2210
# Discriminator_loss:1.1740
#
# EPOCH[5] - STEP[130]
# Generator_loss:1.4543
# L1_loss:0.1594
# Discriminator_loss:1.3884
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.7662
# L1_loss:0.1642
# Discriminator_loss:0.6278
#
# EPOCH[5] - STEP[150]
# Generator_loss:0.9065
# L1_loss:0.1701
# Discriminator_loss:0.7762
#
# EPOCH[5] - STEP[160]
# Generator_loss:2.2045
# L1_loss:0.1674
# Discriminator_loss:0.7624
#
# EPOCH[5] - STEP[170]
# Generator_loss:1.4366
# L1_loss:0.1781
# Discriminator_loss:0.7724
#
# EPOCH[5] - STEP[180]
# Generator_loss:2.1138
# L1_loss:0.1430
# Discriminator_loss:0.4461
#
# EPOCH[5] - STEP[190]
# Generator_loss:2.5521
# L1_loss:0.1715
# Discriminator_loss:1.8266
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.6229
# L1_loss:0.1607
# Discriminator_loss:0.5798
#
# EPOCH[5] - STEP[210]
# Generator_loss:1.7828
# L1_loss:0.1531
# Discriminator_loss:0.5216
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.5882
# L1_loss:0.1768
# Discriminator_loss:1.1294
#
# EPOCH[5] - STEP[230]
# Generator_loss:0.5636
# L1_loss:0.1591
# Discriminator_loss:1.1014
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.7261
# L1_loss:0.2312
# Discriminator_loss:0.8162
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.1038
# L1_loss:0.2187
# Discriminator_loss:0.3606
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.7371
# L1_loss:0.1694
# Discriminator_loss:1.5108
#
# EPOCH[6] - STEP[20]
# Generator_loss:0.8249
# L1_loss:0.2046
# Discriminator_loss:0.8042
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.0463
# L1_loss:0.1933
# Discriminator_loss:0.5517
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.7404
# L1_loss:0.1591
# Discriminator_loss:0.9874
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.8547
# L1_loss:0.1627
# Discriminator_loss:0.9949
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.6633
# L1_loss:0.1638
# Discriminator_loss:0.6744
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.5692
# L1_loss:0.1807
# Discriminator_loss:0.3478
#
# EPOCH[6] - STEP[80]
# Generator_loss:2.2007
# L1_loss:0.1833
# Discriminator_loss:0.5945
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.0303
# L1_loss:0.1744
# Discriminator_loss:0.6089
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.8784
# L1_loss:0.1868
# Discriminator_loss:1.8116
#
# EPOCH[6] - STEP[110]
# Generator_loss:2.4305
# L1_loss:0.1777
# Discriminator_loss:0.4823
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.1875
# L1_loss:0.2080
# Discriminator_loss:0.3590
#
# EPOCH[6] - STEP[130]
# Generator_loss:2.1609
# L1_loss:0.2494
# Discriminator_loss:0.3149
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.0723
# L1_loss:0.1551
# Discriminator_loss:1.4530
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.7992
# L1_loss:0.1669
# Discriminator_loss:1.8126
#
# EPOCH[6] - STEP[160]
# Generator_loss:3.2933
# L1_loss:0.1819
# Discriminator_loss:1.2502
#
# EPOCH[6] - STEP[170]
# Generator_loss:0.6122
# L1_loss:0.1855
# Discriminator_loss:1.3323
#
# EPOCH[6] - STEP[180]
# Generator_loss:2.0179
# L1_loss:0.1942
# Discriminator_loss:0.8908
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.2023
# L1_loss:0.1763
# Discriminator_loss:0.7345
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.6739
# L1_loss:0.1775
# Discriminator_loss:0.9802
#
# EPOCH[6] - STEP[210]
# Generator_loss:0.8386
# L1_loss:0.1783
# Discriminator_loss:0.6678
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.8400
# L1_loss:0.2056
# Discriminator_loss:0.2486
#
# EPOCH[6] - STEP[230]
# Generator_loss:2.3150
# L1_loss:0.1732
# Discriminator_loss:0.8301
#
# EPOCH[6] - STEP[240]
# Generator_loss:0.9756
# L1_loss:0.1763
# Discriminator_loss:0.6502
#
# EPOCH[6] - STEP[250]
# Generator_loss:0.4732
# L1_loss:0.2014
# Discriminator_loss:1.1008
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.3779
# L1_loss:0.1782
# Discriminator_loss:1.1503
#
# EPOCH[7] - STEP[20]
# Generator_loss:2.1544
# L1_loss:0.1703
# Discriminator_loss:0.2961
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.0235
# L1_loss:0.1824
# Discriminator_loss:0.6248
#
# EPOCH[7] - STEP[40]
# Generator_loss:0.6944
# L1_loss:0.1676
# Discriminator_loss:1.3146
#
# EPOCH[7] - STEP[50]
# Generator_loss:1.2293
# L1_loss:0.1641
# Discriminator_loss:0.5580
#
# EPOCH[7] - STEP[60]
# Generator_loss:1.2636
# L1_loss:0.1763
# Discriminator_loss:0.4767
#
# EPOCH[7] - STEP[70]
# Generator_loss:0.7634
# L1_loss:0.1801
# Discriminator_loss:0.8595
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.2485
# L1_loss:0.1802
# Discriminator_loss:0.6271
#
# EPOCH[7] - STEP[90]
# Generator_loss:0.5095
# L1_loss:0.1857
# Discriminator_loss:1.6526
#
# EPOCH[7] - STEP[100]
# Generator_loss:0.0779
# L1_loss:0.2014
# Discriminator_loss:2.9760
#
# EPOCH[7] - STEP[110]
# Generator_loss:1.5903
# L1_loss:0.1513
# Discriminator_loss:0.5757
#
# EPOCH[7] - STEP[120]
# Generator_loss:0.4415
# L1_loss:0.1882
# Discriminator_loss:1.3299
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.7804
# L1_loss:0.1739
# Discriminator_loss:0.3842
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.7880
# L1_loss:0.1899
# Discriminator_loss:0.7361
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.9836
# L1_loss:0.1977
# Discriminator_loss:0.1910
#
# EPOCH[7] - STEP[160]
# Generator_loss:0.4656
# L1_loss:0.1545
# Discriminator_loss:1.6180
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.0876
# L1_loss:0.1794
# Discriminator_loss:0.6852
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.2830
# L1_loss:0.1701
# Discriminator_loss:0.7941
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.3576
# L1_loss:0.1815
# Discriminator_loss:1.0328
#
# EPOCH[7] - STEP[200]
# Generator_loss:3.9335
# L1_loss:0.1737
# Discriminator_loss:1.2258
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.4777
# L1_loss:0.1811
# Discriminator_loss:1.1233
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.7726
# L1_loss:0.1426
# Discriminator_loss:1.6548
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.0387
# L1_loss:0.1726
# Discriminator_loss:0.9240
#
# EPOCH[7] - STEP[240]
# Generator_loss:2.2271
# L1_loss:0.1909
# Discriminator_loss:0.7429
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.0134
# L1_loss:0.2025
# Discriminator_loss:0.6792
#
# EPOCH[8] - STEP[10]
# Generator_loss:0.9307
# L1_loss:0.1537
# Discriminator_loss:1.8229
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.7249
# L1_loss:0.1951
# Discriminator_loss:0.5568
#
# EPOCH[8] - STEP[30]
# Generator_loss:0.5311
# L1_loss:0.1505
# Discriminator_loss:1.3233
#
# EPOCH[8] - STEP[40]
# Generator_loss:2.5801
# L1_loss:0.1632
# Discriminator_loss:2.0286
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.7212
# L1_loss:0.1850
# Discriminator_loss:1.6412
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.9377
# L1_loss:0.1665
# Discriminator_loss:0.9261
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.5398
# L1_loss:0.1648
# Discriminator_loss:1.8637
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.1572
# L1_loss:0.2050
# Discriminator_loss:0.5416
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.1882
# L1_loss:0.2151
# Discriminator_loss:1.2123
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.6887
# L1_loss:0.2244
# Discriminator_loss:0.4686
#
# EPOCH[8] - STEP[110]
# Generator_loss:1.1675
# L1_loss:0.1599
# Discriminator_loss:0.7953
#
# EPOCH[8] - STEP[120]
# Generator_loss:0.8218
# L1_loss:0.1721
# Discriminator_loss:1.0930
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.3434
# L1_loss:0.1797
# Discriminator_loss:0.6674
#
# EPOCH[8] - STEP[140]
# Generator_loss:0.9590
# L1_loss:0.1887
# Discriminator_loss:0.9785
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.8788
# L1_loss:0.1777
# Discriminator_loss:0.3424
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.4441
# L1_loss:0.1838
# Discriminator_loss:0.3938
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.6968
# L1_loss:0.2112
# Discriminator_loss:0.6677
#
# EPOCH[8] - STEP[180]
# Generator_loss:0.5361
# L1_loss:0.1798
# Discriminator_loss:1.0536
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.5377
# L1_loss:0.1950
# Discriminator_loss:0.5699
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.8632
# L1_loss:0.1856
# Discriminator_loss:0.8046
#
# EPOCH[8] - STEP[210]
# Generator_loss:1.8501
# L1_loss:0.1823
# Discriminator_loss:0.6543
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.9107
# L1_loss:0.1760
# Discriminator_loss:1.1297
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.8803
# L1_loss:0.1756
# Discriminator_loss:0.3746
#
# EPOCH[8] - STEP[240]
# Generator_loss:0.7706
# L1_loss:0.1903
# Discriminator_loss:0.7508
#
# EPOCH[8] - STEP[250]
# Generator_loss:2.0099
# L1_loss:0.1964
# Discriminator_loss:1.6253
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.4878
# L1_loss:0.1802
# Discriminator_loss:1.2574
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.3282
# L1_loss:0.2030
# Discriminator_loss:0.4194
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.8063
# L1_loss:0.1782
# Discriminator_loss:1.1378
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.8678
# L1_loss:0.1679
# Discriminator_loss:1.2863
#
# EPOCH[9] - STEP[50]
# Generator_loss:0.8365
# L1_loss:0.1667
# Discriminator_loss:0.7782
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.8105
# L1_loss:0.1643
# Discriminator_loss:0.6110
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.8529
# L1_loss:0.1560
# Discriminator_loss:2.3491
#
# EPOCH[9] - STEP[80]
# Generator_loss:0.5403
# L1_loss:0.1663
# Discriminator_loss:1.1589
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.5114
# L1_loss:0.1625
# Discriminator_loss:1.0003
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.7026
# L1_loss:0.2059
# Discriminator_loss:0.3369
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.4668
# L1_loss:0.1900
# Discriminator_loss:0.4200
#
# EPOCH[9] - STEP[120]
# Generator_loss:0.7670
# L1_loss:0.1650
# Discriminator_loss:1.0608
#
# EPOCH[9] - STEP[130]
# Generator_loss:1.1536
# L1_loss:0.1850
# Discriminator_loss:0.5808
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.2496
# L1_loss:0.2022
# Discriminator_loss:0.8277
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.7057
# L1_loss:0.1746
# Discriminator_loss:0.4353
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.9161
# L1_loss:0.1734
# Discriminator_loss:2.1085
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.4277
# L1_loss:0.1642
# Discriminator_loss:2.0462
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.8463
# L1_loss:0.1905
# Discriminator_loss:0.2914
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.7735
# L1_loss:0.1901
# Discriminator_loss:0.3752
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.9408
# L1_loss:0.2221
# Discriminator_loss:0.2064
#
# EPOCH[9] - STEP[210]
# Generator_loss:1.5267
# L1_loss:0.1613
# Discriminator_loss:0.7731
#
# EPOCH[9] - STEP[220]
# Generator_loss:2.1612
# L1_loss:0.1508
# Discriminator_loss:3.0008
#
# EPOCH[9] - STEP[230]
# Generator_loss:2.4084
# L1_loss:0.1573
# Discriminator_loss:0.6728
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.7885
# L1_loss:0.1857
# Discriminator_loss:0.6997
#
# EPOCH[9] - STEP[250]
# Generator_loss:2.1052
# L1_loss:0.1727
# Discriminator_loss:0.4935
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.7444
# L1_loss:0.1559
# Discriminator_loss:1.5050
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.0943
# L1_loss:0.1754
# Discriminator_loss:0.6554
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.2546
# L1_loss:0.1681
# Discriminator_loss:1.3147
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.1764
# L1_loss:0.1774
# Discriminator_loss:0.3445
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.3118
# L1_loss:0.1596
# Discriminator_loss:0.6522
#
# EPOCH[10] - STEP[60]
# Generator_loss:2.5527
# L1_loss:0.2179
# Discriminator_loss:0.7108
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.3505
# L1_loss:0.2007
# Discriminator_loss:0.6422
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.6743
# L1_loss:0.1634
# Discriminator_loss:0.4192
#
# EPOCH[10] - STEP[90]
# Generator_loss:2.2666
# L1_loss:0.1932
# Discriminator_loss:0.3468
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.8688
# L1_loss:0.1981
# Discriminator_loss:0.7106
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.3115
# L1_loss:0.1913
# Discriminator_loss:0.7760
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.0797
# L1_loss:0.2013
# Discriminator_loss:0.6005
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.1159
# L1_loss:0.1707
# Discriminator_loss:0.8485
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.3816
# L1_loss:0.1817
# Discriminator_loss:0.8695
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.4836
# L1_loss:0.1857
# Discriminator_loss:0.3766
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.8497
# L1_loss:0.1918
# Discriminator_loss:0.3914
#
# EPOCH[10] - STEP[170]
# Generator_loss:2.1661
# L1_loss:0.1678
# Discriminator_loss:1.1729
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.8629
# L1_loss:0.1786
# Discriminator_loss:1.1929
#
# EPOCH[10] - STEP[190]
# Generator_loss:2.2853
# L1_loss:0.1488
# Discriminator_loss:2.4311
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.7072
# L1_loss:0.1599
# Discriminator_loss:2.2009
#
# EPOCH[10] - STEP[210]
# Generator_loss:2.0931
# L1_loss:0.2229
# Discriminator_loss:0.2649
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.0651
# L1_loss:0.1962
# Discriminator_loss:0.6531
#
# EPOCH[10] - STEP[230]
# Generator_loss:0.5734
# L1_loss:0.1609
# Discriminator_loss:2.3270
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.2729
# L1_loss:0.2129
# Discriminator_loss:0.5186
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.7498
# L1_loss:0.1950
# Discriminator_loss:0.9479

# %%
test_ind = 1

test_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/val/'
f = test_path + os.listdir(test_path)[test_ind]
painted, photo = load_img(f)

pred = generator(tf.expand_dims(painted, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(painted))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(photo))
